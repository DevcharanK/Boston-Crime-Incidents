# %%
import pandas as pd

# Read the Excel file
file_path = 'Ed_qual.xlsx'
sheet_name = 'Educational Attainment'
df = pd.read_excel(file_path, sheet_name)
df
# Out:
#                    DISTRICT  Total population 25 years and over  \
# 0                    Boston                              473775
# 1                   Allston                               10432
# 2                  Back Bay                               13791
# 3               Beacon Hill                                8203
# 4                  Brighton                               39650
# 5               Charlestown                               15069
# 6                Dorchester                               86012
# 7                  Downtown                               12722
# 8               East Boston                               33947
# 9                    Fenway                               13202
# 10                Hyde Park                               27240
# 11            Jamaica Plain                               31245
# 12                 Longwood                                 531
# 13                 Mattapan                               18095
# 14             Mission Hill                                9593
# 15                North End                                7136
# 16               Roslindale                               21961
# 17                  Roxbury                               33588
# 18             South Boston                               29731
# 19  South Boston Waterfront                                3897
# 20                South End                               26302
# 21                 West End                                5683
# 22             West Roxbury                               25276
#
#     Less than High School          %  High School Graduate       %.1  \
# 0                    60508  0.127715                 80223  0.169327
# 1                      571  0.054735                   701  0.067197
# 2                      284  0.020593                   565  0.040969
# 3                      169  0.020602                   148  0.018042
# 4                     2660  0.067087                  3968  0.100076
# 5                     1192  0.079103                  1833  0.121640
# 6                    15449  0.179614                 22117  0.257139
# 7                     1963  0.154300                  1123  0.088272
# 8                     9228  0.271836                  8883  0.261673
# 9                      840  0.063627                  1017  0.077034
# 10                    3759  0.137996                  6354  0.233260
# 11                    2490  0.079693                  3203  0.102512
# 12                      17  0.032015                    20  0.037665
# 13                    2632  0.145455                  5323  0.294170
# 14                    1662  0.173251                  1332  0.138851
# 15                     185  0.025925                   512  0.071749
# 16                    2027  0.092300                  3923  0.178635
# 17                    7733  0.230231                  8227  0.244939
# 18                    2350  0.079042                  3681  0.123810
# 19                      80  0.020529                   218  0.055940
# 20                    3094  0.117634                  2387  0.090754
# 21                     333  0.058596                   400  0.070385
# 22                    1650  0.065279                  4187  0.165651
#
#     GED or Alternative Credential       %.2  Some College        %.3  ...  \
# 0                           13163  0.027783          62266  0.131425  ...
# 1                              72  0.006902            886  0.084931  ...
# 2                              31  0.002248            690  0.050033  ...
# 3                              20  0.002438            270  0.032915  ...
# 4                             709  0.017881           4149  0.104641  ...
# 5                             229  0.015197           1243  0.082487  ...
# 6                            3580  0.041622          14716  0.171092  ...
# 7                             222  0.017450            877  0.068936  ...
# 8                             842  0.024803           3900  0.114885  ...
# 9                             291  0.022042           1112  0.084230  ...
# 10                           1196  0.043906           5794  0.212702  ...
# 11                            570  0.018243           3789  0.121267  ...
# 12                             15  0.028249             36  0.067797  ...
# 13                            897  0.049572           4147  0.229179  ...
# 14                            159  0.016575           1449  0.151048  ...
# 15                             11  0.001541            503  0.070488  ...
# 16                            733  0.033377           3535  0.160967  ...
# 17                           1675  0.049869           6363  0.189443  ...
# 18                            558  0.018768           2499  0.084054  ...
# 19                             32  0.008211            173  0.044393  ...
# 20                            540  0.020531           2234  0.084937  ...
# 21                             66  0.011614            396  0.069682  ...
# 22                            700  0.027694           3344  0.132299  ...
#
#     Less than High School .1  %Less than High School  \
# 0                      60508                0.127715
# 1                        571                0.054735
# 2                        284                0.020593
# 3                        169                0.020602
# 4                       2660                0.067087
# 5                       1192                0.079103
# 6                      15449                0.179614
# 7                       1963                0.154300
# 8                       9228                0.271836
# 9                        840                0.063627
# 10                      3759                0.137996
# 11                      2490                0.079693
# 12                        17                0.032015
# 13                      2632                0.145455
# 14                      1662                0.173251
# 15                       185                0.025925
# 16                      2027                0.092300
# 17                      7733                0.230231
# 18                      2350                0.079042
# 19                        80                0.020529
# 20                      3094                0.117634
# 21                       333                0.058596
# 22                      1650                0.065279
#
#     High School Graduate/GED or Alternative Credential       %.7  \
# 0                                               93386   0.197110
# 1                                                 773   0.074099
# 2                                                 596   0.043217
# 3                                                 168   0.020480
# 4                                                4677   0.117957
# 5                                                2062   0.136837
# 6                                               25697   0.298761
# 7                                                1345   0.105722
# 8                                                9725   0.286476
# 9                                                1308   0.099076
# 10                                               7550   0.277166
# 11                                               3773   0.120755
# 12                                                 35   0.065913
# 13                                               6220   0.343741
# 14                                               1491   0.155426
# 15                                                523   0.073290
# 16                                               4656   0.212012
# 17                                               9902   0.294808
# 18                                               4239   0.142578
# 19                                                250   0.064152
# 20                                               2927   0.111284
# 21                                                466   0.081999
# 22                                               4887   0.193345
#
#     Some College/Associate's Degree       %.8  Bachelor's Degree.1  \
# 0                             84255  0.177838               128045
# 1                              1244  0.119248                 4338
# 2                              1130  0.081937                 5396
# 3                               399  0.048641                 3815
# 4                              5477  0.138134                15575
# 5                              1656  0.109894                 4987
# 6                             19657  0.228538                16095
# 7                              1399  0.109967                 3327
# 8                              5182  0.152650                 6413
# 9                              1495  0.113240                 4491
# 10                             8210  0.301395                 5017
# 11                             4675  0.149624                 9304
# 12                               36  0.067797                  208
# 13                             5539  0.306107                 2109
# 14                             1819  0.189617                 2320
# 15                              646  0.090527                 3626
# 16                             4746  0.216110                 5209
# 17                             8273  0.246308                 5048
# 18                             3601  0.121119                12856
# 19                              353  0.090582                 1799
# 20                             3029  0.115162                 7741
# 21                              515  0.090621                 1733
# 22                             5013  0.198330                 6592
#
#    %Bachelor's Degree   Master's Degree or more.1       %.9
# 0            0.270265                      107581  0.227072
# 1            0.415836                        3506  0.336081
# 2            0.391270                        6385  0.462983
# 3            0.465074                        3652  0.445203
# 4            0.392812                       11261  0.284010
# 5            0.330944                        5172  0.343221
# 6            0.187125                        9114  0.105962
# 7            0.261515                        4688  0.368496
# 8            0.188912                        3399  0.100127
# 9            0.340176                        5068  0.383881
# 10           0.184178                        2704  0.099266
# 11           0.297776                       11003  0.352152
# 12           0.391714                         235  0.442561
# 13           0.116552                        1595  0.088146
# 14           0.241843                        2301  0.239862
# 15           0.508128                        2156  0.302130
# 16           0.237193                        5323  0.242384
# 17           0.150292                        2632  0.078361
# 18           0.432411                        6685  0.224849
# 19           0.461637                        1415  0.363100
# 20           0.294312                        9511  0.361607
# 21           0.304945                        2636  0.463840
# 22           0.260801                        7134  0.282244
#
# [23 rows x 29 columns]

# %%
# Calculate the median income for each location
poverty_by_location = df.groupby('DISTRICT')["%Bachelor's Degree"].median()
print(poverty_by_location)
# Out:
# DISTRICT
# Allston                    0.415836
# Back Bay                   0.391270
# Beacon Hill                0.465074
# Boston                     0.270265
# Brighton                   0.392812
# Charlestown                0.330944
# Dorchester                 0.187125
# Downtown                   0.261515
# East Boston                0.188912
# Fenway                     0.340176
# Hyde Park                  0.184178
# Jamaica Plain              0.297776
# Longwood                   0.391714
# Mattapan                   0.116552
# Mission Hill               0.241843
# North End                  0.508128
# Roslindale                 0.237193
# Roxbury                    0.150292
# South Boston               0.432411
# South Boston Waterfront    0.461637
# South End                  0.294312
# West End                   0.304945
# West Roxbury               0.260801
# Name: %Bachelor's Degree, dtype: float64

# %%
crime_df = pd.read_csv('Processed_data.csv')
crime_df
# Out:
# C:\Users\Exam15\AppData\Local\Temp\ipykernel_7392\783833767.py:1: DtypeWarning: Columns (0,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   crime_df = pd.read_csv('Processed_data.csv')
#        INCIDENT_NUMBER  OFFENSE_CODE                    OFFENSE_DESCRIPTION  \
# 0           I152049588           614  LARCENY THEFT FROM MV - NON-ACCESSORY
# 1           I152049593          1874                          DRUGS - OTHER
# 2           I152049594          1874                          DRUGS - OTHER
# 3           I152049463          1402                              VANDALISM
# 4           I152049469           802               ASSAULT SIMPLE - BATTERY
# ...                ...           ...                                    ...
# 216533       232051183           801                       ASSAULT - SIMPLE
# 216534       232056119           613                    LARCENY SHOPLIFTING
# 216535       232066199          1402                              VANDALISM
# 216536       232067269           613                    LARCENY SHOPLIFTING
# 216537       232070395           301                                ROBBERY
#
#        DISTRICT  REPORTING_AREA SHOOTING           OCCURRED_ON_DATE  YEAR  \
# 0            D4           155.0        0        2015-06-15 00:01:00  2015
# 1           C11           289.0        0        2015-06-15 00:01:00  2015
# 2           C11           289.0        0        2015-06-15 00:01:00  2015
# 3           E18           493.0        0        2015-06-15 00:03:00  2015
# 4           D14           809.0        0        2015-06-15 00:45:00  2015
# ...         ...             ...      ...                        ...   ...
# 216533       D4             NaN        0  2023-06-29 16:18:00+00:00  2023
# 216534       D4             NaN        0  2023-07-16 13:55:00+00:00  2023
# 216535       B2             NaN        0  2023-08-18 17:50:00+00:00  2023
# 216536       D4             NaN        0  2023-08-22 15:07:00+00:00  2023
# 216537       A1            93.0        0  2023-09-01 13:18:00+00:00  2023
#
#         MONTH DAY_OF_WEEK  HOUR          STREET        Lat       Long  \
# 0           6      Monday     0      CONCORD SQ  42.341384 -71.078989
# 1           6      Monday     0      HANCOCK ST  42.310434 -71.061340
# 2           6      Monday     0      HANCOCK ST  42.310434 -71.061340
# 3           6      Monday     0   LEXINGTON AVE  42.262551 -71.115822
# 4           6      Monday     0       BAGNAL ST  42.359569 -71.135982
# ...       ...         ...   ...             ...        ...        ...
# 216533      6    Thursday    16       CAMDEN ST  42.338266 -71.081765
# 216534      7      Sunday    13      NEWBURY ST  42.348405 -71.086884
# 216535      8      Friday    17       JUDSON ST  42.319501 -71.075165
# 216536      8     Tuesday    15  HUNTINGTON AVE  42.347309 -71.079152
# 216537      9      Friday    13        UNION ST  42.360687 -71.056873
#
#                                        Location        Tier
# 0                   (42.34138415, -71.07898883)      Tier 3
# 1                   (42.31043400, -71.06134010)  Tier Drugs
# 2                   (42.31043400, -71.06134010)  Tier Drugs
# 3                   (42.26255067, -71.11582205)      Tier 4
# 4                   (42.35956890, -71.13598188)      Tier 2
# ...                                         ...         ...
# 216533   (42.33826649104909, -71.0817645306216)      Tier 2
# 216534  (42.34840532084056, -71.08688391940139)      Tier 3
# 216535  (42.31950147916197, -71.07516529856777)      Tier 4
# 216536  (42.34730934597846, -71.07915218290486)      Tier 3
# 216537  (42.36068738800536, -71.05687337090743)      Tier 3
#
# [216538 rows x 16 columns]

# %%
# Calculate crime rates by district
crime_rates_by_district = crime_df['DISTRICT'].value_counts().reset_index()
crime_rates_by_district.columns = ['DISTRICT', 'CrimeRate']

# %%
# Create a mapping between district names and codes
district_mapping = {
    'Brighton': 'D14',
    'Charlestown': 'A15',
    'Dorchester': 'C11',
    'Downtown': 'A1',
    'East Boston': 'East Boston',
    'Hyde Park': 'E18',
    'Jamaica Plain': 'E13',
    'Mattapan': 'B3',
    'Roxbury': 'B2',
    'South Boston': 'C6',
    'South End': 'D4',
    'West Roxbury': 'E5',
}

# %%
# Map the district names in income data to codes
df['DistrictCode'] = df['DISTRICT'].map(district_mapping)

# %%
# Calculate crime rates by district
crime_rates_by_district = crime_df['DISTRICT'].value_counts().reset_index()

# %%
crime_rates_by_district.columns = ['DistrictCode', 'CrimeRate']

# %%
# Merge with income data
merged_df = pd.merge(crime_rates_by_district, df, on='DistrictCode', how='inner')

# %%
# Calculate correlation matrix
correlation_matrix = merged_df[['CrimeRate', "%Bachelor's Degree"]].corr()

# %%
# Display the crime rates by district
print(crime_rates_by_district)
# Out:
#    DistrictCode  CrimeRate
# 0            D4      34961
# 1            B2      31082
# 2           C11      27409
# 3            A1      25598
# 4            B3      20969
# 5            C6      17025
# 6           D14      14719
# 7           E13      11751
# 8           E18      10362
# 9            A7       9495
# 10           E5       8452
# 11          A15       4633
# 12     External         81
# 13   Outside of          1

# %%
# Display the correlation matrix
print(correlation_matrix)
# Out:
#                     CrimeRate  %Bachelor's Degree
# CrimeRate            1.000000           -0.325835
# %Bachelor's Degree  -0.325835            1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the figure and axes
fig, ax1 = plt.subplots(figsize=(14, 8))

# Plot the trend of median income
sns.lineplot(x='DISTRICT', y="%Bachelor's Degree", data=merged_df, label="%Bachelor's Degree", marker='o', ax=ax1)
ax1.set_xlabel('District')
ax1.set_ylabel("%Bachelor's Degree", color='blue')
ax1.tick_params('y', colors='blue')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, ha='right')

# Create a second y-axis to plot the trend of crime rates
ax2 = ax1.twinx()
sns.lineplot(x='DISTRICT', y='CrimeRate', data=merged_df, label='Crime Rate', marker='s', ax=ax2, color='orange')
ax2.set_ylabel('Crime Rate', color='orange')
ax2.tick_params('y', colors='orange')

# Add legend
ax1.legend(loc='upper left', bbox_to_anchor=(0.7, 1))

# Title
plt.title('Comparison of Bachelors Degree and Crime Rates Across Different Areas')

# Show the plot
plt.show()
# Out:
# C:\Users\Exam15\AppData\Local\Temp\ipykernel_7392\2172501919.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, ha='right')
